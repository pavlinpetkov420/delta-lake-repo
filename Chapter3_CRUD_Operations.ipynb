# %% [markdown]
# # Testing the code from Chapter3 in the book
#
# # C R U D operations

# %%
# Reduce logging
spark.sparkContext.setLogLevel("ERROR")

# %%
# Create database for these examples
spark.sql(
    """
        CREATE DATABASE IF NOT EXISTS exampleDB
    """
)
# Out:
# DataFrame[]

# %%
# Create test data

data = [
    (1, "United Kingdom", "London"),
    (2, "Canada", "Toronto")
]

schema = ["id", "country", "capital"]

df = spark.createDataFrame(data, schema=schema)

# Save as CSV, using pandas write in order to create single file
# PySpark separates the write and created additional files
# path = "/e/Programming/python_project/delta_lake_pyspark_learning/delta-lake-definitive-guide/datasets/my_datasets"
df.toPandas().to_csv("countries.csv", header=None)

# Save table as parquet for further usage
df.write.format("parquet").mode("overwrite").save("spark-warehouse/countries.parquet")

# %%
# !pwd

# %% [markdown]
# # C - Create

# %%
# Ensure table does not exist?!

spark.sql(
    """
DROP TABLE IF EXISTS exampleDB.countries
    """
)
# Out:
# DataFrame[]

# %%
spark.sql(
    """
CREATE TABLE exampleDB.countries (
    id LONG
    , country STRING
    , capital STRING
) USING DELTA
    """
)
# Out:
# DataFrame[]

# %% [markdown]
# How to Create a table in the working directory so it is inspectable
#
#
# ```
# spark.sql("""
# CREATE TABLE exampleDB.countries_loc (
#   id LONG,
#   country STRING,
#   capital STRING
# ) USING DELTA
# LOCATION '/opt/spark/work-dir/countries.delta';
# """)
# ```

# %%
# Standard INSERT Operation

insert_sql = """
INSERT INTO exampleDB.countries VALUES
(1, "United Kingdom", "London")
, (2, "Canada", "Toronto")
"""

spark.sql(
    insert_sql
)
# Out:
# DataFrame[]

# %%
# INSERT INTO from parques file

spark.sql (
    """
    INSERT INTO exampleDB.countries
    SELECT * FROM parquet.`spark-warehouse/countries.parquet`
    """
)
# Out:
# DataFrame[]

# %%
# Simple CTAS statement
spark.sql(
"""
CREATE TABLE exampleDB.countries2 AS
SELECT * FROM exampleDB.countries
""" 
)

# Some issue with the chosen catalog, current one is derby which is in-memory temp catalog
# Out:
# DataFrame[]

# %%
# CONVERT TO DELTA
spark.sql(
    """
CONVERT TO DELTA parquet.`spark-warehouse/countries.parquet`
    """
)
# Out:
# DataFrame[]

# %% [markdown]
# #### Check out the _delta_log and view the contents of the JSON file(s)

# %%
# !tree spark-warehouse/countries.parquet/_delta_log

# %%
spark.sql(
    """
select * from exampleDB.countries
    """
).show(truncate=False, vertical=True)
# Out:
# -RECORD 0-----------------
#  id      | 1
#  country | United Kingdom
#  capital | London
# -RECORD 1-----------------
#  id      | 1
#  country | United Kingdom
#  capital | London
# -RECORD 2-----------------
#  id      | 4
#  country | Romania
#  capital | Bucharest
# -RECORD 3-----------------
#  id      | 6
#  country | Serbia
#  capital | Belgrade
# -RECORD 4-----------------
#  id      | 2
#  country | Canada
#  capital | Toronto
# -RECORD 5-----------------
#  id      | 2
#  country | Canada
#  capital | Toronto
# -RECORD 6-----------------
#  id      | 3
#  country | Bulgaria
#  capital | Sofia
# -RECORD 7-----------------
#  id      | 5
#  country | Grece
#  capital | Athens

# %%
spark.table("exampleDB.countries").show()
# Out:
# +---+--------------+-------+
# | id|       country|capital|
# +---+--------------+-------+
# |  1|United Kingdom| London|
# |  1|United Kingdom| London|
# |  2|        Canada|Toronto|
# |  2|        Canada|Toronto|
# +---+--------------+-------+

# %%
data2 = [
    (3, "Bulgaria", "Sofia")
    ,(4, "Romania", "Bucharest")
]

schema2 = ["id", "country", "capital"]

df2 = spark.createDataFrame(data2, schema2)

df2.write.format("delta").insertInto("exampleDB.countries")

# %%
data2 = [
    (5, "Grece", "Athens")
    ,(6, "Serbia", "Belgrade")
]

schema2 = ["id", "country", "capital"]

df2 = spark.createDataFrame(data2, schema2)

df2.write.format("delta").mode("append").saveAsTable("exampleDB.countries")

# %%
spark.table("exampleDB.countries").orderBy("id").show()
# Out:
# +---+--------------+---------+
# | id|       country|  capital|
# +---+--------------+---------+
# |  1|United Kingdom|   London|
# |  1|United Kingdom|   London|
# |  2|        Canada|  Toronto|
# |  2|        Canada|  Toronto|
# |  3|      Bulgaria|    Sofia|
# |  4|       Romania|Bucharest|
# |  5|         Grece|   Athens|
# |  6|        Serbia| Belgrade|
# +---+--------------+---------+

# %%
# spark.sql("delete from exampleDB.countries where")

spark.sql(
    """
select row_number() over(partition by country order by id) as rn
from exampleDB.countries
order by id
    """
).show()
# Out:
# +---+
# | rn|
# +---+
# |  1|
# |  2|
# |  1|
# |  2|
# |  1|
# |  1|
# |  1|
# |  1|
# +---+

# %% [markdown]
# # Querying data from Delta Lake Table

# %%
# Pythonic way using DeltaTable

from delta.tables import DeltaTable

countries_delta = DeltaTable.forName(spark, "exampleDB.countries")
countries_df = countries_delta.toDF()

countries_df.filter(countries_df.capital == "London").select("id", "country", "capital").show()
# Out:
# +---+-------+-------+
# | id|country|capital|
# +---+-------+-------+
# +---+-------+-------+

# %% [markdown]
#  ## Read delta tables using Time Travel
#  Time Travel allow us to query older versions of delta tables.
#  For instance: Create 1 table, then insert 2 records, then update 1 of them, then insert 1 new.
#  We have 4 versions so far, 1st empty table structure, 2nd with 2 records, 3rd 2 records 1 is updated, 4th 4 records.

# %% [markdown]
# ### VERSION AS OF

# %%
# SQL way
spark.sql(
    """
SELECT DISTINCT id 
FROM exampleDB.countries 
VERSION AS OF 2
ORDER BY ID ASC
    """
).show()
# Out:
# +---+
# | id|
# +---+
# |  1|
# |  2|
# +---+

# %%
# Python way
# Paths in this cell must start with file: + windows path to directory
# Maybe because of the spark engine load logic OR simply because of the derby metastore? IDK
spark.read \
.option("versionAsOf", "1") \
.load("<your-path-to-table-here>") \
.select("id") \
.distinct() \
.orderBy("id") \
.show()
# Out:
# +---+
# | id|
# +---+
# |  1|
# |  2|
# |  3|
# |  4|
# |  5|
# |  6|
# +---+

# %% [markdown]
# ### DESRIBE HISTORY & TIMESTAMP AS OF
#
# In case we use TIMESTAMP AS OF, we need accurate timestamp in order to retrieve any data.
# For that purpose we first use `DESCSRIBE HISTORY {DB.TABLE}` statement, to display the versions and take accurated timestamp.
# Then it is used in the SELECT SQL with time travel and response is returned.

# %%
spark.sql(
    """
DESCRIBE HISTORY exampleDB.countries;
    """
).show(truncate=False, vertical=True)
# Out:
# -RECORD 0-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  version             | 9
#  timestamp           | 2025-02-24 19:31:03.42
#  userId              | NULL
#  userName            | NULL
#  operation           | DELETE
#  operationParameters | {predicate -> ["(id#1321L = 4)"]}
#  job                 | NULL
#  notebook            | NULL
#  clusterId           | NULL
#  readVersion         | 8
#  isolationLevel      | Serializable
#  isBlindAppend       | false
#  operationMetrics    | {numRemovedFiles -> 1, numRemovedBytes -> 1019, numCopiedRows -> 0, numDeletionVectorsAdded -> 0, numDeletionVectorsRemoved -> 0, numAddedChangeFiles -> 0, executionTimeMs -> 581, numDeletionVectorsUpdated -> 0, numDeletedRows -> 1, scanTimeMs -> 437, numAddedFiles -> 0, numAddedBytes -> 0, rewriteTimeMs -> 144}
#  userMetadata        | NULL
#  engineInfo          | Apache-Spark/3.5.4 Delta-Lake/3.2.0
# -RECORD 1-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  version             | 8
#  timestamp           | 2025-02-24 19:29:51.28
#  userId              | NULL
#  userName            | NULL
#  operation           | DELETE
#  operationParameters | {predicate -> ["(id#1321L = 2)"]}
#  job                 | NULL
#  notebook            | NULL
#  clusterId           | NULL
#  readVersion         | 7
#  isolationLevel      | Serializable
#  isBlindAppend       | false
#  operationMetrics    | {numRemovedFiles -> 2, numRemovedBytes -> 1996, numCopiedRows -> 0, numDeletionVectorsAdded -> 0, numDeletionVectorsRemoved -> 0, numAddedChangeFiles -> 0, executionTimeMs -> 542, numDeletionVectorsUpdated -> 0, numDeletedRows -> 2, scanTimeMs -> 386, numAddedFiles -> 0, numAddedBytes -> 0, rewriteTimeMs -> 156}
#  userMetadata        | NULL
#  engineInfo          | Apache-Spark/3.5.4 Delta-Lake/3.2.0
# -RECORD 2-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  version             | 7
#  timestamp           | 2025-02-24 19:27:13.967
#  userId              | NULL
#  userName            | NULL
#  operation           | DELETE
#  operationParameters | {predicate -> ["(id#986L = 1)"]}
#  job                 | NULL
#  notebook            | NULL
#  clusterId           | NULL
#  readVersion         | 6
#  isolationLevel      | Serializable
#  isBlindAppend       | false
#  operationMetrics    | {numRemovedFiles -> 2, numRemovedBytes -> 2094, numCopiedRows -> 0, numDeletionVectorsAdded -> 0, numDeletionVectorsRemoved -> 0, numAddedChangeFiles -> 0, executionTimeMs -> 1342, numDeletionVectorsUpdated -> 0, numDeletedRows -> 2, scanTimeMs -> 839, numAddedFiles -> 0, numAddedBytes -> 0, rewriteTimeMs -> 502}
#  userMetadata        | NULL
#  engineInfo          | Apache-Spark/3.5.4 Delta-Lake/3.2.0
# -RECORD 3-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  version             | 6
#  timestamp           | 2025-02-24 19:19:16.977
#  userId              | NULL
#  userName            | NULL
#  operation           | UPDATE
#  operationParameters | {predicate -> ["(id#3202L = 3)"]}
#  job                 | NULL
#  notebook            | NULL
#  clusterId           | NULL
#  readVersion         | 5
#  isolationLevel      | Serializable
#  isBlindAppend       | false
#  operationMetrics    | {numRemovedFiles -> 1, numRemovedBytes -> 990, numCopiedRows -> 0, numDeletionVectorsAdded -> 0, numDeletionVectorsRemoved -> 0, numAddedChangeFiles -> 0, executionTimeMs -> 934, numDeletionVectorsUpdated -> 0, scanTimeMs -> 720, numAddedFiles -> 1, numUpdatedRows -> 1, numAddedBytes -> 997, rewriteTimeMs -> 213}
#  userMetadata        | NULL
#  engineInfo          | Apache-Spark/3.5.4 Delta-Lake/3.2.0
# -RECORD 4-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  version             | 5
#  timestamp           | 2025-02-24 19:19:10.559
#  userId              | NULL
#  userName            | NULL
#  operation           | UPDATE
#  operationParameters | {predicate -> ["(id#6626L = 3)"]}
#  job                 | NULL
#  notebook            | NULL
#  clusterId           | NULL
#  readVersion         | 4
#  isolationLevel      | Serializable
#  isBlindAppend       | false
#  operationMetrics    | {numRemovedFiles -> 1, numRemovedBytes -> 997, numCopiedRows -> 0, numDeletionVectorsAdded -> 0, numDeletionVectorsRemoved -> 0, numAddedChangeFiles -> 0, executionTimeMs -> 589, numDeletionVectorsUpdated -> 0, scanTimeMs -> 445, numAddedFiles -> 1, numUpdatedRows -> 1, numAddedBytes -> 990, rewriteTimeMs -> 142}
#  userMetadata        | NULL
#  engineInfo          | Apache-Spark/3.5.4 Delta-Lake/3.2.0
# -RECORD 5-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  version             | 4
#  timestamp           | 2025-02-24 19:13:54.763
#  userId              | NULL
#  userName            | NULL
#  operation           | WRITE
#  operationParameters | {mode -> Append, partitionBy -> []}
#  job                 | NULL
#  notebook            | NULL
#  clusterId           | NULL
#  readVersion         | 3
#  isolationLevel      | Serializable
#  isBlindAppend       | true
#  operationMetrics    | {numFiles -> 3, numOutputRows -> 2, numOutputBytes -> 2461}
#  userMetadata        | NULL
#  engineInfo          | Apache-Spark/3.5.4 Delta-Lake/3.2.0
# -RECORD 6-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  version             | 3
#  timestamp           | 2025-02-24 19:13:43.614
#  userId              | NULL
#  userName            | NULL
#  operation           | WRITE
#  operationParameters | {mode -> Append, partitionBy -> []}
#  job                 | NULL
#  notebook            | NULL
#  clusterId           | NULL
#  readVersion         | 2
#  isolationLevel      | Serializable
#  isBlindAppend       | true
#  operationMetrics    | {numFiles -> 3, numOutputRows -> 2, numOutputBytes -> 2489}
#  userMetadata        | NULL
#  engineInfo          | Apache-Spark/3.5.4 Delta-Lake/3.2.0
# -RECORD 7-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  version             | 2
#  timestamp           | 2025-02-24 19:12:42.331
#  userId              | NULL
#  userName            | NULL
#  operation           | WRITE
#  operationParameters | {mode -> Append, partitionBy -> []}
#  job                 | NULL
#  notebook            | NULL
#  clusterId           | NULL
#  readVersion         | 1
#  isolationLevel      | Serializable
#  isBlindAppend       | true
#  operationMetrics    | {numFiles -> 2, numOutputRows -> 2, numOutputBytes -> 2045}
#  userMetadata        | NULL
#  engineInfo          | Apache-Spark/3.5.4 Delta-Lake/3.2.0
# -RECORD 8-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  version             | 1
#  timestamp           | 2025-02-24 19:12:30.175
#  userId              | NULL
#  userName            | NULL
#  operation           | WRITE
#  operationParameters | {mode -> Append, partitionBy -> []}
#  job                 | NULL
#  notebook            | NULL
#  clusterId           | NULL
#  readVersion         | 0
#  isolationLevel      | Serializable
#  isBlindAppend       | true
#  operationMetrics    | {numFiles -> 2, numOutputRows -> 2, numOutputBytes -> 2045}
#  userMetadata        | NULL
#  engineInfo          | Apache-Spark/3.5.4 Delta-Lake/3.2.0
# -RECORD 9-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  version             | 0
#  timestamp           | 2025-02-24 19:12:23.649
#  userId              | NULL
#  userName            | NULL
#  operation           | CREATE TABLE
#  operationParameters | {partitionBy -> [], clusterBy -> [], description -> NULL, isManaged -> true, properties -> {}}
#  job                 | NULL
#  notebook            | NULL
#  clusterId           | NULL
#  readVersion         | NULL
#  isolationLevel      | Serializable
#  isBlindAppend       | true
#  operationMetrics    | {}
#  userMetadata        | NULL
#  engineInfo          | Apache-Spark/3.5.4 Delta-Lake/3.2.0

# %%
# SQL way
spark.sql(
    """
    SELECT COUNT(*)
    FROM exampleDB.countries
    TIMESTAMP AS OF "2025-02-24 19:13:54"
    """
).show()
# Out:
# +--------+
# |count(1)|
# +--------+
# |       6|
# +--------+

# %%
# Python way
spark.read \
.option("timestampAsOf", "2025-02-24 19:12:42.331") \
.load("<your-path-to>/spark-warehouse/exampledb.db/countries") \
.count()
# Out:
# 8

# %% [markdown]
# ### Update
# In this section, we are going to update a single records using SQL and Python way
#
# First update will change capital to 1 country with wrong city, then we will revert the action with another update

# %%
# SQL way
spark.sql(
"""
UPDATE exampleDB.countries
SET capital = "Ruse"
WHERE id = 3
""" 
)
# Out:
# DataFrame[num_affected_rows: bigint]

# %%
# Read table to see update
spark.sql(
    """
    SELECT *
    FROM exampleDB.countries
    WHERE id = 3
    """
).show()
# Out:
# +---+--------+-------+
# | id| country|capital|
# +---+--------+-------+
# |  3|Bulgaria|   Ruse|
# +---+--------+-------+

# %%
# Notes:
# - the new value in set clause must be wrapped first in double then in single quotes 
# Reason: Engine treats the value in double quotes as a column, if the single quotes are missing!

from pyspark.sql import functions as f

countries_delta.update(
    condition = f.expr("id = 3"),
    set = {"capital": "'Sofia'"}
)

# %%
# Read table to see update
spark.sql(
    """
    SELECT *
    FROM exampleDB.countries
    WHERE id = 3
    """
).show()
# Out:
# +---+-------+--------------+---+
# | id|country|       capital|id2|
# +---+-------+--------------+---+
# |  3|    U.S|Washington D.C|  0|
# +---+-------+--------------+---+

# %% [markdown]
# ### Delete
# In this section, we are going to DELETE records using SQL and Python way

# %%
# SQL

spark.sql(
    """
DELETE FROM exampleDB.countries
WHERE id = 1
    """
)
# Out:
# DataFrame[num_affected_rows: bigint]

# %%
countries_df.select("id", "country", "capital").orderBy("id").show()
# Out:
# +---+--------+---------+
# | id| country|  capital|
# +---+--------+---------+
# |  2|  Canada|  Toronto|
# |  2|  Canada|  Toronto|
# |  3|Bulgaria|    Sofia|
# |  4| Romania|Bucharest|
# |  5|   Grece|   Athens|
# |  6|  Serbia| Belgrade|
# +---+--------+---------+

# %%
# Pythonic way

countries_delta.delete("id = 2")

# %%
countries_df.select("id", "country", "capital").orderBy("id").show()
# Out:
# +---+--------+--------+
# | id| country| capital|
# +---+--------+--------+
# |  3|Bulgaria|   Sofia|
# |  5|   Grece|  Athens|
# |  6|  Serbia|Belgrade|
# +---+--------+--------+

# %%
from pyspark.sql import functions as f

countries_delta.delete(f.col("id") == 4)

# %%
countries_df.select("id", "country", "capital").orderBy("id").show()
# Out:
# +---+--------+--------+
# | id| country| capital|
# +---+--------+--------+
# |  3|Bulgaria|   Sofia|
# |  5|   Grece|  Athens|
# |  6|  Serbia|Belgrade|
# +---+--------+--------+

# %% [markdown]
# ### Overwriting Data in a Delta Lake Table

# %%
# Python
new_data = [
    (1, "United Kingdom", "London", 1)
    ,(2, "Canada", "Toronto", 2)
    ,(3, "Bulgaria", "Sofia", 3)
    ,(4, "Romania", "Bucharest", 4)
    ,(5, "Grece", "Athens", 5)
    ,(6, "Serbia", "Belgrade", 6)
]

schema = ["id", "country", "capital", "id2"]

replace_df = spark.createDataFrame(data=new_data, schema=schema)

# Replace the schema with new
# Old records are removed, table is empty
delta_table2 = (
 DeltaTable.replace(spark)
 .tableName("exampleDB.countries")
 .addColumns(replace_df.schema)
 .execute()
 )

# %%
spark.sql(
    """
select * 
from exampleDB.countries 
order by id
    """
).show()
# Out:
# +---+-------+-------+---+
# | id|country|capital|id2|
# +---+-------+-------+---+
# +---+-------+-------+---+

# %%
# Overwrite SPARK API
replace_df.write.format("delta").mode("overwrite").saveAsTable("exampleDB.countries")

# %%
spark.sql(
    """
select * 
from exampleDB.countries 
order by id
    """
).show()
# Out:
# +---+--------------+---------+
# | id|       country|  capital|
# +---+--------------+---------+
# |  1|United Kingdom|   London|
# |  2|        Canada|  Toronto|
# |  3|      Bulgaria|    Sofia|
# |  4|       Romania|Bucharest|
# |  5|         Grece|   Athens|
# |  6|        Serbia| Belgrade|
# +---+--------------+---------+

# %%
# INSERT OVERWRITE - Overwrites entire table, with the data from VALUES

spark.sql(
    """
INSERT OVERWRITE exampleDB.countries
VALUES(3, 'U.S', "Washington D.C", 0)
    """
)
# Out:
# DataFrame[]

# %%
spark.sql(
    """
select * 
from exampleDB.countries 
order by id
    """
).show()
# Out:
# +---+-------+--------------+---+
# | id|country|       capital|id2|
# +---+-------+--------------+---+
# |  3|    U.S|Washington D.C|  0|
# +---+-------+--------------+---+

# %%
spark.sql(
    """
DESCRIBE HISTORY exampleDB.countries;
    """
).show(truncate=False, vertical=True)
# Out:
# -RECORD 0-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  version             | 17
#  timestamp           | 2025-03-01 19:21:56.319
#  userId              | NULL
#  userName            | NULL
#  operation           | DROP COLUMNS
#  operationParameters | {columns -> ["id2"]}
#  job                 | NULL
#  notebook            | NULL
#  clusterId           | NULL
#  readVersion         | 16
#  isolationLevel      | Serializable
#  isBlindAppend       | true
#  operationMetrics    | {}
#  userMetadata        | NULL
#  engineInfo          | Apache-Spark/3.5.4 Delta-Lake/3.2.0
# -RECORD 1-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  version             | 16
#  timestamp           | 2025-03-01 19:21:51.355
#  userId              | NULL
#  userName            | NULL
#  operation           | SET TBLPROPERTIES
#  operationParameters | {properties -> {"delta.columnMapping.mode":"name","delta.minReaderVersion":"2","delta.minWriterVersion":"5"}}
#  job                 | NULL
#  notebook            | NULL
#  clusterId           | NULL
#  readVersion         | 15
#  isolationLevel      | Serializable
#  isBlindAppend       | true
#  operationMetrics    | {}
#  userMetadata        | NULL
#  engineInfo          | Apache-Spark/3.5.4 Delta-Lake/3.2.0
# -RECORD 2-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  version             | 15
#  timestamp           | 2025-03-01 19:11:05.564
#  userId              | NULL
#  userName            | NULL
#  operation           | CREATE OR REPLACE TABLE AS SELECT
#  operationParameters | {partitionBy -> [], clusterBy -> [], description -> NULL, isManaged -> true, properties -> {}}
#  job                 | NULL
#  notebook            | NULL
#  clusterId           | NULL
#  readVersion         | 14
#  isolationLevel      | Serializable
#  isBlindAppend       | false
#  operationMetrics    | {numFiles -> 7, numOutputRows -> 6, numOutputBytes -> 8070}
#  userMetadata        | NULL
#  engineInfo          | Apache-Spark/3.5.4 Delta-Lake/3.2.0
# -RECORD 3-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  version             | 14
#  timestamp           | 2025-03-01 19:10:09.892
#  userId              | NULL
#  userName            | NULL
#  operation           | REPLACE TABLE
#  operationParameters | {partitionBy -> [], clusterBy -> [], description -> NULL, isManaged -> true, properties -> {}}
#  job                 | NULL
#  notebook            | NULL
#  clusterId           | NULL
#  readVersion         | 13
#  isolationLevel      | Serializable
#  isBlindAppend       | false
#  operationMetrics    | {}
#  userMetadata        | NULL
#  engineInfo          | Apache-Spark/3.5.4 Delta-Lake/3.2.0
# -RECORD 4-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  version             | 13
#  timestamp           | 2025-02-24 19:50:16.973
#  userId              | NULL
#  userName            | NULL
#  operation           | WRITE
#  operationParameters | {mode -> Overwrite, partitionBy -> []}
#  job                 | NULL
#  notebook            | NULL
#  clusterId           | NULL
#  readVersion         | 12
#  isolationLevel      | Serializable
#  isBlindAppend       | false
#  operationMetrics    | {numFiles -> 1, numOutputRows -> 1, numOutputBytes -> 1272}
#  userMetadata        | NULL
#  engineInfo          | Apache-Spark/3.5.4 Delta-Lake/3.2.0
# -RECORD 5-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  version             | 12
#  timestamp           | 2025-02-24 19:48:55.589
#  userId              | NULL
#  userName            | NULL
#  operation           | CREATE OR REPLACE TABLE AS SELECT
#  operationParameters | {partitionBy -> [], clusterBy -> [], description -> NULL, isManaged -> true, properties -> {}}
#  job                 | NULL
#  notebook            | NULL
#  clusterId           | NULL
#  readVersion         | 11
#  isolationLevel      | Serializable
#  isBlindAppend       | false
#  operationMetrics    | {numFiles -> 7, numOutputRows -> 6, numOutputBytes -> 8070}
#  userMetadata        | NULL
#  engineInfo          | Apache-Spark/3.5.4 Delta-Lake/3.2.0
# -RECORD 6-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  version             | 11
#  timestamp           | 2025-02-24 19:46:28.877
#  userId              | NULL
#  userName            | NULL
#  operation           | REPLACE TABLE
#  operationParameters | {partitionBy -> [], clusterBy -> [], description -> NULL, isManaged -> true, properties -> {}}
#  job                 | NULL
#  notebook            | NULL
#  clusterId           | NULL
#  readVersion         | 10
#  isolationLevel      | Serializable
#  isBlindAppend       | false
#  operationMetrics    | {}
#  userMetadata        | NULL
#  engineInfo          | Apache-Spark/3.5.4 Delta-Lake/3.2.0
# -RECORD 7-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  version             | 10
#  timestamp           | 2025-02-24 19:43:41.491
#  userId              | NULL
#  userName            | NULL
#  operation           | REPLACE TABLE
#  operationParameters | {partitionBy -> [], clusterBy -> [], description -> NULL, isManaged -> true, properties -> {}}
#  job                 | NULL
#  notebook            | NULL
#  clusterId           | NULL
#  readVersion         | 9
#  isolationLevel      | Serializable
#  isBlindAppend       | false
#  operationMetrics    | {}
#  userMetadata        | NULL
#  engineInfo          | Apache-Spark/3.5.4 Delta-Lake/3.2.0
# -RECORD 8-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  version             | 9
#  timestamp           | 2025-02-24 19:31:03.42
#  userId              | NULL
#  userName            | NULL
#  operation           | DELETE
#  operationParameters | {predicate -> ["(id#1321L = 4)"]}
#  job                 | NULL
#  notebook            | NULL
#  clusterId           | NULL
#  readVersion         | 8
#  isolationLevel      | Serializable
#  isBlindAppend       | false
# ...
# -RECORD 15----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  version             | 2
#  timestamp           | 2025-02-24 19:12:42.331
#  userId              | NULL
#  userName            | NULL
#  operation           | WRITE
#  operationParameters | {mode -> Append, partitionBy -> []}
#  job                 | NULL
#  notebook            | NULL
#  clusterId           | NULL
#  readVersion         | 1
#  isolationLevel      | Serializable
#  isBlindAppend       | true
#  operationMetrics    | {numFiles -> 2, numOutputRows -> 2, numOutputBytes -> 2045}
#  userMetadata        | NULL
#  engineInfo          | Apache-Spark/3.5.4 Delta-Lake/3.2.0
# -RECORD 16----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  version             | 1
#  timestamp           | 2025-02-24 19:12:30.175
#  userId              | NULL
#  userName            | NULL
#  operation           | WRITE
#  operationParameters | {mode -> Append, partitionBy -> []}
#  job                 | NULL
#  notebook            | NULL
#  clusterId           | NULL
#  readVersion         | 0
#  isolationLevel      | Serializable
#  isBlindAppend       | true
#  operationMetrics    | {numFiles -> 2, numOutputRows -> 2, numOutputBytes -> 2045}
#  userMetadata        | NULL
#  engineInfo          | Apache-Spark/3.5.4 Delta-Lake/3.2.0
# -RECORD 17----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  version             | 0
#  timestamp           | 2025-02-24 19:12:23.649
#  userId              | NULL
#  userName            | NULL
#  operation           | CREATE TABLE
#  operationParameters | {partitionBy -> [], clusterBy -> [], description -> NULL, isManaged -> true, properties -> {}}
#  job                 | NULL
#  notebook            | NULL
#  clusterId           | NULL
#  readVersion         | NULL
#  isolationLevel      | Serializable
#  isBlindAppend       | true
#  operationMetrics    | {}
#  userMetadata        | NULL
#  engineInfo          | Apache-Spark/3.5.4 Delta-Lake/3.2.0

# %%
# In order to drop a column in next cell
# I had to update the table properties to the ones in SQL below

spark.sql(
    """
        ALTER TABLE exampleDB.countries 
        SET TBLPROPERTIES (
            'delta.columnMapping.mode' = 'name',
            'delta.minReaderVersion' = '2',
            'delta.minWriterVersion' = '5'
        )
    """)
# Out:
# DataFrame[]

# %%
# See comment in cell above
spark.sql("ALTER TABLE exampleDB.countries DROP COLUMN id2")
# Out:
# DataFrame[]

# %%
spark.sql("select * from exampleDB.countries2").show()
# Out:
# +---+--------------------+---------+
# | id|             country|  capital|
# +---+--------------------+---------+
# |  7|              France|    Paris|
# |  8|             Germany|   Berlin|
# |  9|Dutchland/Netherl...|Amsterdam|
# | 10|               Italy|     Rome|
# +---+--------------------+---------+

# %%
# Content in cell above was different before truncating, it had duplicated
spark.sql('TRUNCATE TABLE exampleDB.countries2')
# Out:
# DataFrame[]

# %% [markdown]
# ### MERGE / UPSERT

# %%
spark.sql(
    """
INSERT INTO exampleDB.countries2
VALUES (7, 'France', 'Paris')
, (8, 'Germany', 'Berlin')
, (9, 'Dutchland/Netherlands', 'Amsterdam')
, (10, 'Italy', 'Rome')
    """
)
# Out:
# DataFrame[]

# %%
# Inserting the correct pairs of country/capital in order to use it as a source for the merge statement
spark.sql(
    """
INSERT INTO exampleDB.countries2
VALUES (11, 'Spain', "Madrid") -- Madrid
, (12, 'Belgium', 'Brussels') -- Brussels
, (13, 'Czech Republic', 'Prague') -- Prague
    """
)
# Out:
# DataFrame[]

# %%
# Inserting few rows with wrong capitals in order to update them with MERGE statement
spark.sql(
    """
INSERT INTO exampleDB.countries
VALUES (11, 'Spain', "Barcelona") -- Madrid
, (12, 'Belgium', 'Liège') -- Brussels
, (13, 'Czech Republic', 'Brno') -- Prague
    """
)
# Out:
# DataFrame[]

# %%
# SQL

spark.sql(
    """
        MERGE INTO exampleDB.countries A -- Target
        USING (SELECT * FROM exampleDB.countries2) B -- Source
            ON A.id = B.id -- Matching condition, mostly PK is used
        WHEN MATCHED THEN -- Action when A.PK = B.PK
          UPDATE SET -- Action
            id = A.id
            , country = B.country
            , capital = B.capital
        WHEN NOT MATCHED -- Action when PK not match
            THEN INSERT ( -- Action
                id
                , country
                , capital
            )
            VALUES (
                B.id
                , B.country
                , B.capital
            )
    """
)
# Out:
# DataFrame[num_affected_rows: bigint, num_updated_rows: bigint, num_deleted_rows: bigint, num_inserted_rows: bigint]

# %%
spark.sql("select * from exampleDB.countries ORDER BY id").show()
# Out:
# +---+--------------------+---------+
# | id|             country|  capital|
# +---+--------------------+---------+
# |  1|      United Kingdom|   London|
# |  2|              Canada|  Toronto|
# |  3|            Bulgaria|    Sofia|
# |  4|             Romania|Bucharest|
# |  5|               Grece|   Athens|
# |  6|              Serbia| Belgrade|
# |  7|              France|    Paris|
# |  8|             Germany|   Berlin|
# |  9|Dutchland/Netherl...|Amsterdam|
# | 10|               Italy|     Rome|
# | 11|               Spain|   Madrid|
# | 12|             Belgium| Brussels|
# | 13|      Czech Republic|   Prague|
# +---+--------------------+---------+

# %%
# Preparation for Python merge
spark.sql(
    """
        INSERT INTO exampleDB.countries
        VALUES (14, 'Norway', "Bergen") -- Oslo is the correct one 
    """
)
# Out:
# DataFrame[]

# %%
# Preparation for new UPSERT source
source_df = (
    spark.createDataFrame(
        [
            (14, 'Norway', "Oslo")
            ,(15, 'Monaco', 'Monaco') 
        ], schema=['id', 'country', 'capital']
    )
)

# %%
# UPSERT with Delta API
from delta.tables import DeltaTable
# Create DeltaTable object
countries_delta = DeltaTable.forName(spark, "exampleDB.countries")

countries_delta.alias('target').merge(
    source = source_df.alias('source')
    , condition = 'source.id = target.id'
).whenMatchedUpdate(
    set = {
        'country': 'source.country'
        , 'capital': 'source.capital'
    }
).whenNotMatchedInsert(
    values = {
        'id': 'source.id'
        , 'country': 'source.country'
        , 'capital': 'source.capital'
    }
).execute()

# %%
# Executed before MERGE Statement above
spark.sql("select * from exampleDB.countries ORDER BY id").show()
# Out:
# +---+--------------------+---------+
# | id|             country|  capital|
# +---+--------------------+---------+
# |  1|      United Kingdom|   London|
# |  2|              Canada|  Toronto|
# |  3|            Bulgaria|    Sofia|
# |  4|             Romania|Bucharest|
# |  5|               Grece|   Athens|
# |  6|              Serbia| Belgrade|
# |  7|              France|    Paris|
# |  8|             Germany|   Berlin|
# |  9|Dutchland/Netherl...|Amsterdam|
# | 10|               Italy|     Rome|
# | 11|               Spain|   Madrid|
# | 12|             Belgium| Brussels|
# | 13|      Czech Republic|   Prague|
# | 14|              Norway|   Bergen|
# +---+--------------------+---------+

# %%
# Executed after MERGE Statement above
spark.sql("select * from exampleDB.countries ORDER BY id").show()
# Out:
# +---+--------------------+---------+
# | id|             country|  capital|
# +---+--------------------+---------+
# |  1|      United Kingdom|   London|
# |  2|              Canada|  Toronto|
# |  3|            Bulgaria|    Sofia|
# |  4|             Romania|Bucharest|
# |  5|               Grece|   Athens|
# |  6|              Serbia| Belgrade|
# |  7|              France|    Paris|
# |  8|             Germany|   Berlin|
# |  9|Dutchland/Netherl...|Amsterdam|
# | 10|               Italy|     Rome|
# | 11|               Spain|   Madrid|
# | 12|             Belgium| Brussels|
# | 13|      Czech Republic|   Prague|
# | 14|              Norway|     Oslo|
# | 15|              Monaco|   Monaco|
# +---+--------------------+---------+

# %% [markdown]
# ### Other Useful Actions
# - Parquet Conversions
# - Other Useful Actions

# %%
# Parquet/Iceberg Conversion - Not executed, only written for practice
# Parquet conversion was already tested in the cells in above sections

# %%
# SQL
# Important Note: If table is already partition, it is required to specify the partition columns with a PARTITION BY clause
spark.sql( 
    """
        CONVERT TO DELTA parquet`spark-warehouse/countries.parquet`
    """
)

# %%
# Delta API
from delta.tables import DeltaTable

converted_delta_table = (
    DeltaTable.convertToDelta(
        spark,
        "parquet.`spark-warehouse/countries.parquet`"
    )
)

# %%
'''Iceberg conversion
The DeltaTable API does not support the Iceberg
conversion. Spark SQL, however, can support the conversion with CONVERT TO
DELTA, but you will also need to install support for the Iceberg format in your Spark
environment -> additional JAR file (delta-iceberg)
Unlike conversion from parquet, iceberg conversion infers PARTITIONING metadata from source

There’s one more thing you should know about this conversion process. An interest‐
ing side effect exists in converted Iceberg tables. Since both Iceberg and Delta Lake
maintain distinctly separate transaction logs, none of the new files added through
interactions via Delta Lake will be registered on the Iceberg side. However, since
the Iceberg log is not removed, the new Delta Lake table will still be readable and
accessible as an Iceberg table

SQL:
'''
spark.sql("CONVERT TO DELTA iceberg.`countries.iceberg`")

# %%
# Delta Lake Metadata and History

# %%
# SQL
spark.sql("DESCRIBE DETAIL exampleDB.countries2").show(truncate=False, vertical=True)

# %%
# Python
# countries_delta.details() - Returns Spark DataFrame
countries_delta.detail().show(truncate=False, vertical=True)

# %%
# SQL
spark.sql("DESCRIBE HISTORY exampleDB.countries").show(truncate=False, vertical=True)
# Out:
# -RECORD 0----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  version             | 21
#  timestamp           | 2025-03-01 19:51:23.781
#  userId              | NULL
#  userName            | NULL
#  operation           | MERGE
#  operationParameters | {predicate -> ["(id#9768L = id#10685L)"], matchedPredicates -> [{"actionType":"update"}], notMatchedPredicates -> [{"actionType":"insert"}], notMatchedBySourcePredicates -> []}
#  job                 | NULL
#  notebook            | NULL
#  clusterId           | NULL
#  readVersion         | 20
#  isolationLevel      | Serializable
#  isBlindAppend       | false
#  operationMetrics    | {numTargetRowsCopied -> 0, numTargetRowsDeleted -> 0, numTargetFilesAdded -> 1, numTargetBytesAdded -> 1257, numTargetBytesRemoved -> 1268, numTargetDeletionVectorsAdded -> 0, numTargetRowsMatchedUpdated -> 1, executionTimeMs -> 9712, numTargetRowsInserted -> 1, numTargetRowsMatchedDeleted -> 0, numTargetDeletionVectorsUpdated -> 0, scanTimeMs -> 573, numTargetRowsUpdated -> 1, numOutputRows -> 2, numTargetDeletionVectorsRemoved -> 0, numTargetRowsNotMatchedBySourceUpdated -> 0, numTargetChangeFilesAdded -> 0, numSourceRows -> 2, numTargetFilesRemoved -> 1, numTargetRowsNotMatchedBySourceDeleted -> 0, rewriteTimeMs -> 294}
#  userMetadata        | NULL
#  engineInfo          | Apache-Spark/3.5.4 Delta-Lake/3.2.0
# -RECORD 1----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  version             | 20
#  timestamp           | 2025-03-01 19:45:01.011
#  userId              | NULL
#  userName            | NULL
#  operation           | WRITE
#  operationParameters | {mode -> Append, partitionBy -> []}
#  job                 | NULL
#  notebook            | NULL
#  clusterId           | NULL
#  readVersion         | 19
#  isolationLevel      | Serializable
#  isBlindAppend       | true
#  operationMetrics    | {numFiles -> 1, numOutputRows -> 1, numOutputBytes -> 1268}
#  userMetadata        | NULL
#  engineInfo          | Apache-Spark/3.5.4 Delta-Lake/3.2.0
# -RECORD 2----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  version             | 19
#  timestamp           | 2025-03-01 19:41:04.219
#  userId              | NULL
#  userName            | NULL
#  operation           | MERGE
#  operationParameters | {predicate -> ["(id#6388L = id#6391L)"], matchedPredicates -> [{"actionType":"update"}], notMatchedPredicates -> [{"actionType":"insert"}], notMatchedBySourcePredicates -> []}
#  job                 | NULL
#  notebook            | NULL
#  clusterId           | NULL
#  readVersion         | 18
#  isolationLevel      | Serializable
#  isBlindAppend       | false
#  operationMetrics    | {numTargetRowsCopied -> 0, numTargetRowsDeleted -> 0, numTargetFilesAdded -> 1, numTargetBytesAdded -> 1431, numTargetBytesRemoved -> 3867, numTargetDeletionVectorsAdded -> 0, numTargetRowsMatchedUpdated -> 3, executionTimeMs -> 3190, numTargetRowsInserted -> 4, numTargetRowsMatchedDeleted -> 0, numTargetDeletionVectorsUpdated -> 0, scanTimeMs -> 2564, numTargetRowsUpdated -> 3, numOutputRows -> 7, numTargetDeletionVectorsRemoved -> 0, numTargetRowsNotMatchedBySourceUpdated -> 0, numTargetChangeFilesAdded -> 0, numSourceRows -> 7, numTargetFilesRemoved -> 3, numTargetRowsNotMatchedBySourceDeleted -> 0, rewriteTimeMs -> 422}
#  userMetadata        | NULL
#  engineInfo          | Apache-Spark/3.5.4 Delta-Lake/3.2.0
# -RECORD 3----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  version             | 18
#  timestamp           | 2025-03-01 19:35:16.882
#  userId              | NULL
#  userName            | NULL
#  operation           | WRITE
#  operationParameters | {mode -> Append, partitionBy -> []}
#  job                 | NULL
#  notebook            | NULL
#  clusterId           | NULL
#  readVersion         | 17
#  isolationLevel      | Serializable
#  isBlindAppend       | true
#  operationMetrics    | {numFiles -> 3, numOutputRows -> 3, numOutputBytes -> 3867}
#  userMetadata        | NULL
#  engineInfo          | Apache-Spark/3.5.4 Delta-Lake/3.2.0
# -RECORD 4----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  version             | 17
#  timestamp           | 2025-03-01 19:21:56.319
#  userId              | NULL
#  userName            | NULL
#  operation           | DROP COLUMNS
#  operationParameters | {columns -> ["id2"]}
#  job                 | NULL
#  notebook            | NULL
# ...
#  notebook            | NULL
#  clusterId           | NULL
#  readVersion         | 2
#  isolationLevel      | Serializable
#  isBlindAppend       | true
#  operationMetrics    | {numFiles -> 3, numOutputRows -> 2, numOutputBytes -> 2489}
#  userMetadata        | NULL
#  engineInfo          | Apache-Spark/3.5.4 Delta-Lake/3.2.0
# -RECORD 19---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  version             | 2
#  timestamp           | 2025-02-24 19:12:42.331
#  userId              | NULL
#  userName            | NULL
#  operation           | WRITE
#  operationParameters | {mode -> Append, partitionBy -> []}
#  job                 | NULL
#  notebook            | NULL
#  clusterId           | NULL
#  readVersion         | 1
#  isolationLevel      | Serializable
#  isBlindAppend       | true
#  operationMetrics    | {numFiles -> 2, numOutputRows -> 2, numOutputBytes -> 2045}
#  userMetadata        | NULL
#  engineInfo          | Apache-Spark/3.5.4 Delta-Lake/3.2.0
# only showing top 20 rows

# %%
# Python
countries_delta.history().show(truncate=False, vertical=True)
# Out:
# -RECORD 0----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  version             | 21
#  timestamp           | 2025-03-01 19:51:23.781
#  userId              | NULL
#  userName            | NULL
#  operation           | MERGE
#  operationParameters | {predicate -> ["(id#9768L = id#10685L)"], matchedPredicates -> [{"actionType":"update"}], notMatchedPredicates -> [{"actionType":"insert"}], notMatchedBySourcePredicates -> []}
#  job                 | NULL
#  notebook            | NULL
#  clusterId           | NULL
#  readVersion         | 20
#  isolationLevel      | Serializable
#  isBlindAppend       | false
#  operationMetrics    | {numTargetRowsCopied -> 0, numTargetRowsDeleted -> 0, numTargetFilesAdded -> 1, numTargetBytesAdded -> 1257, numTargetBytesRemoved -> 1268, numTargetDeletionVectorsAdded -> 0, numTargetRowsMatchedUpdated -> 1, executionTimeMs -> 9712, numTargetRowsInserted -> 1, numTargetRowsMatchedDeleted -> 0, numTargetDeletionVectorsUpdated -> 0, scanTimeMs -> 573, numTargetRowsUpdated -> 1, numOutputRows -> 2, numTargetDeletionVectorsRemoved -> 0, numTargetRowsNotMatchedBySourceUpdated -> 0, numTargetChangeFilesAdded -> 0, numSourceRows -> 2, numTargetFilesRemoved -> 1, numTargetRowsNotMatchedBySourceDeleted -> 0, rewriteTimeMs -> 294}
#  userMetadata        | NULL
#  engineInfo          | Apache-Spark/3.5.4 Delta-Lake/3.2.0
# -RECORD 1----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  version             | 20
#  timestamp           | 2025-03-01 19:45:01.011
#  userId              | NULL
#  userName            | NULL
#  operation           | WRITE
#  operationParameters | {mode -> Append, partitionBy -> []}
#  job                 | NULL
#  notebook            | NULL
#  clusterId           | NULL
#  readVersion         | 19
#  isolationLevel      | Serializable
#  isBlindAppend       | true
#  operationMetrics    | {numFiles -> 1, numOutputRows -> 1, numOutputBytes -> 1268}
#  userMetadata        | NULL
#  engineInfo          | Apache-Spark/3.5.4 Delta-Lake/3.2.0
# -RECORD 2----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  version             | 19
#  timestamp           | 2025-03-01 19:41:04.219
#  userId              | NULL
#  userName            | NULL
#  operation           | MERGE
#  operationParameters | {predicate -> ["(id#6388L = id#6391L)"], matchedPredicates -> [{"actionType":"update"}], notMatchedPredicates -> [{"actionType":"insert"}], notMatchedBySourcePredicates -> []}
#  job                 | NULL
#  notebook            | NULL
#  clusterId           | NULL
#  readVersion         | 18
#  isolationLevel      | Serializable
#  isBlindAppend       | false
#  operationMetrics    | {numTargetRowsCopied -> 0, numTargetRowsDeleted -> 0, numTargetFilesAdded -> 1, numTargetBytesAdded -> 1431, numTargetBytesRemoved -> 3867, numTargetDeletionVectorsAdded -> 0, numTargetRowsMatchedUpdated -> 3, executionTimeMs -> 3190, numTargetRowsInserted -> 4, numTargetRowsMatchedDeleted -> 0, numTargetDeletionVectorsUpdated -> 0, scanTimeMs -> 2564, numTargetRowsUpdated -> 3, numOutputRows -> 7, numTargetDeletionVectorsRemoved -> 0, numTargetRowsNotMatchedBySourceUpdated -> 0, numTargetChangeFilesAdded -> 0, numSourceRows -> 7, numTargetFilesRemoved -> 3, numTargetRowsNotMatchedBySourceDeleted -> 0, rewriteTimeMs -> 422}
#  userMetadata        | NULL
#  engineInfo          | Apache-Spark/3.5.4 Delta-Lake/3.2.0
# -RECORD 3----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  version             | 18
#  timestamp           | 2025-03-01 19:35:16.882
#  userId              | NULL
#  userName            | NULL
#  operation           | WRITE
#  operationParameters | {mode -> Append, partitionBy -> []}
#  job                 | NULL
#  notebook            | NULL
#  clusterId           | NULL
#  readVersion         | 17
#  isolationLevel      | Serializable
#  isBlindAppend       | true
#  operationMetrics    | {numFiles -> 3, numOutputRows -> 3, numOutputBytes -> 3867}
#  userMetadata        | NULL
#  engineInfo          | Apache-Spark/3.5.4 Delta-Lake/3.2.0
# -RECORD 4----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  version             | 17
#  timestamp           | 2025-03-01 19:21:56.319
#  userId              | NULL
#  userName            | NULL
#  operation           | DROP COLUMNS
#  operationParameters | {columns -> ["id2"]}
#  job                 | NULL
#  notebook            | NULL
# ...
#  notebook            | NULL
#  clusterId           | NULL
#  readVersion         | 2
#  isolationLevel      | Serializable
#  isBlindAppend       | true
#  operationMetrics    | {numFiles -> 3, numOutputRows -> 2, numOutputBytes -> 2489}
#  userMetadata        | NULL
#  engineInfo          | Apache-Spark/3.5.4 Delta-Lake/3.2.0
# -RECORD 19---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  version             | 2
#  timestamp           | 2025-02-24 19:12:42.331
#  userId              | NULL
#  userName            | NULL
#  operation           | WRITE
#  operationParameters | {mode -> Append, partitionBy -> []}
#  job                 | NULL
#  notebook            | NULL
#  clusterId           | NULL
#  readVersion         | 1
#  isolationLevel      | Serializable
#  isBlindAppend       | true
#  operationMetrics    | {numFiles -> 2, numOutputRows -> 2, numOutputBytes -> 2045}
#  userMetadata        | NULL
#  engineInfo          | Apache-Spark/3.5.4 Delta-Lake/3.2.0
# only showing top 20 rows

# %% [markdown]
# # Finished!
